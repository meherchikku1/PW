# %% [markdown]
# Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# *  Flask is a lightweight Python web framework, known for its simplicity and flexibility, used to build web applications and APIs with minimal overhead and the freedom to choose components.

# %% [markdown]
# * Advantages of flask framework include simplicity, flexibility, extensibility, minimalism, rapid development, a rich ecosystem of extensions, and a large community, making it ideal for building web applications and APIs.

# %% [markdown]
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def hello_world():
    return "<h1> Hello, World!</h1>"

if __name__ == "__main__":
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.18.0.3:5000
# Press CTRL+C to quit

# %%
pip install flask

# %% [markdown]
# ![Screenshot 2023-09-17 210540.png](attachment:c86d5a8d-97bb-4e65-9581-5a8cdd204d7a.png)

# %% [markdown]
# Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# ans:
# * App routing in Flask refers to defining URL patterns and associating them with specific functions (view functions) to handle incoming HTTP requests. It determines how different URLs map to various parts of your application, allowing for dynamic content generation based on the requested URL.

# %% [markdown]
# * We use app routes in Flask to define URL patterns and link them to view functions, enabling the web application to respond appropriately to different URLs with specific content or actions.

# %%
Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
route to show the following details:
Company Name: ABC Corporation
Location: India
Contact Detail: 999-999-9999

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/welcome")
def hello_world():
    return "Welcome to ABC Corporation..."

@app.route("/")
def hello_world1():
    return "Company Name: ABC Corporation"
    return "Location: India"
    return  "Contact Detail: 999-999-9999"

if __name__ == "__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
# url_for() function.

# %% [markdown]
# ans:
# * In Flask, the url_for() function is used for URL building. It generates URLs for view functions based on their names and any arguments provided, making it easier to create dynamic links in your application.

# %%
from flask import Flask, url_for

app = Flask(__name__)

@app.route('/')
def home():
    return 'Welcome to the home page!'


if __name__ == '__main__':
    with app.test_request_context():
        home_url = url_for('home')
        about_url = url_for('about')

    print(f'URL for home: {home_url}')
